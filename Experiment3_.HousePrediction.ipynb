# %%
import kagglehub, os, pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

path = kagglehub.dataset_download("alyelbadry/house-pricing-dataset")
df = pd.read_csv(os.path.join(path, os.listdir(path)[0]))

df = df.drop(columns=[c for c in ['id','date'] if c in df.columns])

df = pd.get_dummies(df, drop_first=True)

X, y = df.drop('price', axis=1), df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.fit(X_train, y_train, epochs=200, verbose=0)

pred = model.predict(X_test[:1])
print("Predicted:", pred[0][0])
print("Actual:", y_test.iloc[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted: 222449.31
# Actual: 225000.0

# %%
pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kagglehub in ./.local/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in ./.local/lib/python3.11/site-packages (from kagglehub) (0.1.18)
# Requirement already satisfied: packaging in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from kagglehub) (24.1)
# Requirement already satisfied: pyyaml in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from kagglehub) (4.66.5)
# Requirement already satisfied: protobuf in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (6.31.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/intel/oneapi/intelpython/lib/python3.11/site-packages (from requests->kagglehub) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
